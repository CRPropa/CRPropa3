# %%
from pylab import *
import random as rd
import numpy as np
import pandas as pd
import math
import crtools as crt
# Out:
# Import error: crpropa
# Limited functionality

# %%
Data1 = crt.Simulation('Series9_Part1000000_SourceE10.0_Step10000.0kpc_Obs1000.0Mpc_Sprotons.txt')
Data1.loadData()
Filter = crt.Filtering(Data1)
Filter.addAction(Filter.rangeCut, ['ID', 22, 22])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_g10=Filtered.get(['E'])

Filter = crt.Filtering(Data1)
Filter.addAction(Filter.rangeCut, ['ID', 12, 12])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_en10=Filtered.get(['E'])

Filter = crt.Filtering(Data1)
Filter.addAction(Filter.rangeCut, ['ID', 11, 11])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_e10=Filtered.get(['E'])

# %%
Data50 = crt.Simulation('Series9_Part1000000_SourceE10.0_Step10000.0kpc_Obs1000.0Mpc_Sprotons.txt')
Data50.loadData()
Filter = crt.Filtering(Data50)
Filter.addAction(Filter.rangeCut, ['ID', 22, 22])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_g50_2=Filtered.get(['E'])

Filter = crt.Filtering(Data50)
Filter.addAction(Filter.rangeCut, ['ID', 12, 12])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_en50_2=Filtered.get(['E'])

Filter = crt.Filtering(Data50)
Filter.addAction(Filter.rangeCut, ['ID', 11, 11])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_e50_2=Filtered.get(['E'])

# %%
Data2 = crt.Simulation('Series9_Part1000000_SourceE10.0_Step20000.0kpc_Obs1000.0Mpc_Sprotons.txt')
Data2.loadData()
Filter = crt.Filtering(Data2)
Filter.addAction(Filter.rangeCut, ['ID', 22, 22])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_g20=Filtered.get(['E'])

Filter = crt.Filtering(Data2)
Filter.addAction(Filter.rangeCut, ['ID', 12, 12])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_en20=Filtered.get(['E'])

Filter = crt.Filtering(Data2)
Filter.addAction(Filter.rangeCut, ['ID', 11, 11])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_e20=Filtered.get(['E'])

# %%
Data3 = crt.Simulation('Series9_Part1000000_SourceE10.0_Step30000.0kpc_Obs1000.0Mpc_Sprotons.txt')
Data3.loadData()
Filter = crt.Filtering(Data3)
Filter.addAction(Filter.rangeCut, ['ID', 22, 22])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_g30=Filtered.get(['E'])

Filter = crt.Filtering(Data3)
Filter.addAction(Filter.rangeCut, ['ID', 12, 12])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_en30=Filtered.get(['E'])

Filter = crt.Filtering(Data3)
Filter.addAction(Filter.rangeCut, ['ID', 11, 11])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_e30=Filtered.get(['E'])

# %%
Data4 = crt.Simulation('Series9_Part1000000_SourceE10.0_Step40000.0kpc_Obs1000.0Mpc_Sprotons.txt')
Data4.loadData()
Filter = crt.Filtering(Data4)
Filter.addAction(Filter.rangeCut, ['ID', 22, 22])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_g40=Filtered.get(['E'])

Filter = crt.Filtering(Data4)
Filter.addAction(Filter.rangeCut, ['ID', 12, 12])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_en40=Filtered.get(['E'])

Filter = crt.Filtering(Data4)
Filter.addAction(Filter.rangeCut, ['ID', 11, 11])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_e40=Filtered.get(['E'])

# %%
Data5 = crt.Simulation('Series9_Part1000000_SourceE10.0_Step50000.0kpc_Obs1000.0Mpc_Sprotons.txt')
Data5.loadData()
Filter = crt.Filtering(Data5)
Filter.addAction(Filter.rangeCut, ['ID', 22, 22])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_g50=Filtered.get(['E'])

Filter = crt.Filtering(Data5)
Filter.addAction(Filter.rangeCut, ['ID', 12, 12])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_en50=Filtered.get(['E'])

Filter = crt.Filtering(Data5)
Filter.addAction(Filter.rangeCut, ['ID', 11, 11])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_e50=Filtered.get(['E'])

# %%
Data6 = crt.Simulation('Series9_Part1000000_SourceE10.0_Step60000.0kpc_Obs1000.0Mpc_Sprotons.txt')
Data6.loadData()
Filter = crt.Filtering(Data6)
Filter.addAction(Filter.rangeCut, ['ID', 22, 22])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_g60=Filtered.get(['E'])

Filter = crt.Filtering(Data6)
Filter.addAction(Filter.rangeCut, ['ID', 12, 12])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_en60=Filtered.get(['E'])

Filter = crt.Filtering(Data6)
Filter.addAction(Filter.rangeCut, ['ID', 11, 11])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_e60=Filtered.get(['E'])

# %%
Data7 = crt.Simulation('Series9_Part1000000_SourceE10.0_Step70000.0kpc_Obs1000.0Mpc_Sprotons.txt')
Data7.loadData()
Filter = crt.Filtering(Data7)
Filter.addAction(Filter.rangeCut, ['ID', 22, 22])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_g70=Filtered.get(['E'])

Filter = crt.Filtering(Data7)
Filter.addAction(Filter.rangeCut, ['ID', 12, 12])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_en70=Filtered.get(['E'])

Filter = crt.Filtering(Data7)
Filter.addAction(Filter.rangeCut, ['ID', 11, 11])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_e70=Filtered.get(['E'])

# %%
Data8 = crt.Simulation('Series9_Part1000000_SourceE10.0_Step80000.0kpc_Obs1000.0Mpc_Sprotons.txt')
Data8.loadData()
Filter = crt.Filtering(Data8)
Filter.addAction(Filter.rangeCut, ['ID', 22, 22])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_g80=Filtered.get(['E'])

Filter = crt.Filtering(Data8)
Filter.addAction(Filter.rangeCut, ['ID', 12, 12])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_en80=Filtered.get(['E'])

Filter = crt.Filtering(Data8)
Filter.addAction(Filter.rangeCut, ['ID', 11, 11])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_e80=Filtered.get(['E'])

# %%
Data9 = crt.Simulation('Series9_Part1000000_SourceE10.0_Step90000.0kpc_Obs1000.0Mpc_Sprotons.txt')
Data9.loadData()
Filter = crt.Filtering(Data9)
Filter.addAction(Filter.rangeCut, ['ID', 22, 22])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_g90=Filtered.get(['E'])

Filter = crt.Filtering(Data9)
Filter.addAction(Filter.rangeCut, ['ID', 12, 12])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_en90=Filtered.get(['E'])

Filter = crt.Filtering(Data9)
Filter.addAction(Filter.rangeCut, ['ID', 11, 11])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_e90=Filtered.get(['E'])

# %%
Data10 = crt.Simulation('Series7_Part10000000_SourceE10.0_Step50000.0kpc_Obs100.0Mpc_Sprotons.txt')
Data10.loadData()
Filter = crt.Filtering(Data10)
Filter.addAction(Filter.rangeCut, ['ID', 22, 22])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_g100=Filtered.get(['E'])

Filter = crt.Filtering(Data10)
Filter.addAction(Filter.rangeCut, ['ID', 12, 12])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_en100=Filtered.get(['E'])

Filter = crt.Filtering(Data10)
Filter.addAction(Filter.rangeCut, ['ID', 11, 11])
Filter.performActions()

Filtered = Filter.getFiltered()
e_dist_e100=Filtered.get(['E'])

# %%
nob =100

Edges = np.logspace(-2, 1, nob)

g10, binEdges_g=np.histogram(e_dist_g10, bins=Edges)
en10, binEdges_g=np.histogram(e_dist_en10, bins=Edges)
e10, binEdges_g=np.histogram(e_dist_e10, bins=Edges)
g20, binEdges_g=np.histogram(e_dist_g20, bins=Edges)
en20, binEdges_g=np.histogram(e_dist_en20, bins=Edges)
e20, binEdges_g=np.histogram(e_dist_e20, bins=Edges)
g30, binEdges_g=np.histogram(e_dist_g30, bins=Edges)
en30, binEdges_g=np.histogram(e_dist_en30, bins=Edges)
e30, binEdges_g=np.histogram(e_dist_e30, bins=Edges)
g40, binEdges_g=np.histogram(e_dist_g40, bins=Edges)
en40, binEdges_g=np.histogram(e_dist_en40, bins=Edges)
e40, binEdges_g=np.histogram(e_dist_e40, bins=Edges)
g50, binEdges_g=np.histogram(e_dist_g50, bins=Edges)
en50, binEdges_g=np.histogram(e_dist_en50, bins=Edges)
e50, binEdges_g=np.histogram(e_dist_e50, bins=Edges)
g60, binEdges_g=np.histogram(e_dist_g60, bins=Edges)
en60, binEdges_g=np.histogram(e_dist_en60, bins=Edges)
e60, binEdges_g=np.histogram(e_dist_e60, bins=Edges)
g70, binEdges_g=np.histogram(e_dist_g70, bins=Edges)
en70, binEdges_g=np.histogram(e_dist_en70, bins=Edges)
e70, binEdges_g=np.histogram(e_dist_e70, bins=Edges)
g80, binEdges_g=np.histogram(e_dist_g80, bins=Edges)
en80, binEdges_g=np.histogram(e_dist_en80, bins=Edges)
e80, binEdges_g=np.histogram(e_dist_e80, bins=Edges)
g90, binEdges_g=np.histogram(e_dist_g90, bins=Edges)
en90, binEdges_g=np.histogram(e_dist_en90, bins=Edges)
e90, binEdges_g=np.histogram(e_dist_e90, bins=Edges)
g100, binEdges_g=np.histogram(e_dist_g100, bins=Edges)
en100, binEdges_g=np.histogram(e_dist_en100, bins=Edges)
e100, binEdges_g=np.histogram(e_dist_e100, bins=Edges)
binMiddle_g=(binEdges_g[1:]-binEdges_g[:-1])/2.+binEdges_g[:-1]

# %%
fig=plt.figure()
plt.plot(binMiddle_g, g10*binMiddle_g**2, label='Gamma 50')
#plt.plot(binMiddle_g, g10_2*binMiddle_g**2, label='Gamma 50 sev I')
#plt.plot(binMiddle_g, en10*binMiddle_g**2, label='En 50')
#plt.plot(binMiddle_g, e10*binMiddle_g**2,  label='E 50')
plt.plot(binMiddle_g, g20*binMiddle_g**2, label='Gamma 100')
#plt.plot(binMiddle_g, en20*binMiddle_g**2, label='En 100')
#plt.plot(binMiddle_g, e20*binMiddle_g**2, label='E 100')
plt.plot(binMiddle_g, g30*binMiddle_g**2, label='Gamma 150')
#plt.plot(binMiddle_g, en30*binMiddle_g**2, label='En 150')
#plt.plot(binMiddle_g, e30*binMiddle_g**2, label='E 150')
plt.plot(binMiddle_g, g40*binMiddle_g**2, label='Gamma 200')
#plt.plot(binMiddle_g, en40*binMiddle_g**2, label='En 200')
#plt.plot(binMiddle_g, e40*binMiddle_g**2,  label='E 200')
plt.plot(binMiddle_g, g50*binMiddle_g**2, label='Gamma 250')
#plt.plot(binMiddle_g, en50*binMiddle_g**2, label='En 250')
#plt.plot(binMiddle_g, e50*binMiddle_g**2,label='E 250')
plt.plot(binMiddle_g, g60*binMiddle_g**2, label='Gamma 300')
#plt.plot(binMiddle_g, en60*binMiddle_g**2, label='En 300')
#plt.plot(binMiddle_g, e60*binMiddle_g**2, label='E 300')
plt.plot(binMiddle_g, g70*binMiddle_g**2, label='Gamma 350')
#plt.plot(binMiddle_g, en70*binMiddle_g**2, label='En 350')
#plt.plot(binMiddle_g, e70*binMiddle_g**2, label='E 350')
plt.plot(binMiddle_g, g80*binMiddle_g**2, label='Gamma 400')
#plt.plot(binMiddle_g, en80*binMiddle_g**2, label='En 400')
#plt.plot(binMiddle_g, e80*binMiddle_g**2, label='E 400')
plt.plot(binMiddle_g, g90*binMiddle_g**2, label='Gamma 450')
#plt.plot(binMiddle_g, en90*binMiddle_g**2, label='En 450')
#plt.plot(binMiddle_g, e90*binMiddle_g**2, label='E 450')
#plt.plot(binMiddle_g, g100*binMiddle_g**2, color='blue', label='Gamma 500')
#plt.plot(binMiddle_g, en100*binMiddle_g**2, label='En 500')
#plt.plot(binMiddle_g, e100*binMiddle_g**2, color='blue', label='E 500')

#plt.legend(loc='upper left')
plt.xlabel('Energy E in TeV')
plt.ylabel('Energy Spectrum E^2 dN/dE')
plt.loglog()
plt.show()
fig.savefig('/home/home1/jce/Steplength/Series9_gamma_all_steps.png')

plt.close(fig)
