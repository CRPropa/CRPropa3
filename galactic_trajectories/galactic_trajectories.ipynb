# %% [markdown]
# # Galactic trajectories
# The following codes performs a backtracking simulation in the JF2012 model and visualizes the trajectories.
# A custom simulation module is used for a numbered trajectory output, that simplifies the plotting later on.

# %%
from crpropa import *


# magnetic field setup
B = JF12Field()
# seed = 691342
# B.randomStriated(seed)
# B.randomTurbulent(seed)

# simulation setup
modules = ModuleList()
modules.add(PropagationCK(B, 1e-4, 0.1 * parsec, 100 * parsec))
modules.add(LargeObserverSphere(Vector3d(0), 20 * kpc))

class MyTrajectoryOutput(Module):
    """
    Custom trajectory output: i, x, y, z
    where i is a running cosmic ray number
    and x,y,z are the galactocentric coordinates in [kpc].
    Use with OMP_NUM_THREADS=1 (not thread-safe)
    """
    def __init__(self, fname):
        Module.__init__(self)
        self.fout = open(fname, 'w')
        self.fout.write('#i\tX\tY\tZ\n')
        self.i = 0
    def process(self, c):
        v = c.current.getPosition() / kpc
        self.fout.write('%i\t%.3f\t%.3f\t%.3f\n'%(self.i, v.x, v.y, v.z))
        if not(c.isActive()):
            self.i += 1

t = MyTrajectoryOutput('galactic_trajectories.txt')
modules.add(t)


# source setup
source = Source()
source.add(SourcePosition(Vector3d(-8.5, 0, 0) * kpc))
source.add(SourceIsotropicEmission())
source.add(SourceParticleType(- nucleusId(1,1)))
source.add(SourceEnergy(10 * EeV))

modules.run(source, 20)  # backtrack 10 random cosmic rays

# %% [markdown]
# ## 3D trajectory plot

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import axes3d
from pylab import *

figure(figsize=(12,12))
ax = subplot(111, projection='3d', aspect='equal')

# plot trajectories
I,X,Y,Z = genfromtxt('galactic_trajectories.txt', unpack=True, skip_footer=1)
for i in range(int(max(I))):
    idx = I == i
    ax.plot(X[idx], Y[idx], Z[idx], c='b', lw=1, alpha=0.5)

# plot galactic border
r = 20
u, v = meshgrid(linspace(0, 2*pi, 100), linspace(0, pi, 100))
x = r * cos(u) * sin(v)
y = r * sin(u) * sin(v)
z = r * cos(v)
ax.plot_surface(x, y, z, rstride=2, cstride=2, color='r', alpha=0.1, lw=0)
ax.plot_wireframe(x, y, z, rstride=10, cstride=10, color='k', alpha=0.5, lw=0.3)

# plot galactic center
ax.scatter(0,0,0, marker='o', color='k')
# plot earth
ax.scatter(-8.5,0,0, marker='o', color='b')

ax.tick_params(axis='both', which='major', labelsize=16)
ax.tick_params(axis='both', which='minor', labelsize=16)
ax.set_xlabel('x / kpc', fontsize=18)
ax.set_ylabel('y / kpc', fontsize=18)
ax.set_zlabel('z / kpc', fontsize=18)
ax.set_xlim((-20, 20))
ax.set_ylim((-20, 20))
ax.set_zlim((-20, 20))
ax.xaxis.set_ticks((-20,-10,0,10,20))
ax.yaxis.set_ticks((-20,-10,0,10,20))
ax.zaxis.set_ticks((-20,-10,0,10,20))
# Out:
# /usr/lib/python2.7/site-packages/numpy/lib/npyio.py:1407: UserWarning: genfromtxt: Empty input file: "galactic_trajectories.txt"
#   warnings.warn('genfromtxt: Empty input file: "%s"' % fname)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-1c9d02a8a885> in <module>()
#       7
#       8 # plot trajectories
# ----> 9 I,X,Y,Z = genfromtxt('galactic_trajectories.txt', unpack=True, skip_footer=1)
#      10 for i in range(int(max(I))):
#      11     idx = I == i
#
# ValueError: need more than 0 values to unpack
